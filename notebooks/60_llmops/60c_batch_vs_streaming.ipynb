# %% [markdown]
# # 60c — Batch vs Streaming
#
# **Goal:** Compare batch generation with SSE streaming.
#
# **Inputs:** Prompt set
#
# **Outputs:** Latency comparison
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Batch vs streaming placeholder.')
