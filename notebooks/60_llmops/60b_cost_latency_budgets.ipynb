# %% [markdown]
# # 60b — Cost & Latency Budgets
#
# **Goal:** Measure throughput and prompt caching.
#
# **Inputs:** Workload params
#
# **Outputs:** Throughput metrics
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Budgeting placeholder. Measure tokens/sec here.')
