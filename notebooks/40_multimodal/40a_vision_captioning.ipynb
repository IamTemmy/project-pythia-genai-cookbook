# %% [markdown]
# # 40a — Vision Captioning
#
# **Goal:** Image → caption pipeline.
#
# **Inputs:** Images
#
# **Outputs:** Captions
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Vision captioning placeholder.')
