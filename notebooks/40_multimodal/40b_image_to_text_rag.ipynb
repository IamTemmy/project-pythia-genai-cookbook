# %% [markdown]
# # 40b — Image-to-Text RAG
#
# **Goal:** OCR and visual embeddings → RAG.
#
# **Inputs:** Images/PDFs
#
# **Outputs:** Grounded answers
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Image-to-text RAG placeholder.')
