# %% [markdown]
# # 50c — Human Preference Arena
#
# **Goal:** A/B testing UI for comparing prompts/models.
#
# **Inputs:** Two model configs
#
# **Outputs:** Preference dataset
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Arena placeholder. Use Gradio to collect pairwise prefs.')
