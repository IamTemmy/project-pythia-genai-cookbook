# %% [markdown]
# # 50a — Text Generation Evaluation
#
# **Goal:** Compute automatic metrics and collect human prefs.
#
# **Inputs:** Model outputs + references
#
# **Outputs:** Scores
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Eval placeholder. Compute BLEU/ROUGE/BERTScore here.')
