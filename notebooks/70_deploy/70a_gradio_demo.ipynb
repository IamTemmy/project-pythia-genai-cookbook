# %% [markdown]
# # 70a — Gradio Demo
#
# **Goal:** Ship a simple chat/app demo.
#
# **Inputs:** User text
#
# **Outputs:** UI app
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
import gradio as gr
def echo(txt): return f"Pythia says: {txt}"
gr.Interface(fn=echo, inputs="text", outputs="text", title="Pythia Echo").launch(share=False)
