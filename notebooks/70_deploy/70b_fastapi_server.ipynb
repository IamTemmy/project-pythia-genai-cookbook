# %% [markdown]
# # 70b — FastAPI Server
#
# **Goal:** Minimal inference server with /generate.
#
# **Inputs:** HTTP request
#
# **Outputs:** JSON
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
# Run with: uvicorn app:app --reload
from fastapi import FastAPI
app = FastAPI()
@app.get("/generate")
def generate(q: str): return {"output": f"Pythia echoes: {q}"}
print("Create app.py with this code to run the server.")
