# %% [markdown]
# # 30b — LoRA Instruction Tuning
#
# **Goal:** Adapt a base model for instruction following.
#
# **Inputs:** See cells
#
# **Outputs:** Artifacts/prints
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('Placeholder notebook. Fill in when ready.')
