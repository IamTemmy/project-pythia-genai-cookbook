# %% [markdown]
# # 30a — LoRA Text Classification
#
# **Goal:** PEFT fine-tune for classification.
#
# **Inputs:** Labeled texts
#
# **Outputs:** Adapter weights
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
print('LoRA training script placeholder. Add trainer code when ready.')
