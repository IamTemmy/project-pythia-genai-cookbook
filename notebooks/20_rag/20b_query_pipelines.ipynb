# %% [markdown]
# # 20b — Query Pipelines
#
# **Goal:** Retrieve → rerank → generate.
#
# **Inputs:** User question
#
# **Outputs:** Answer with retrieved snippets
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
question = 'What is this cookbook about?'
print('Answer (stub): Project Pythia focuses on practical GenAI recipes.')
