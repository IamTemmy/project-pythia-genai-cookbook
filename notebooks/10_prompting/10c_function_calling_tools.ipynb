# %% [markdown]
# # 10c — Tool / Function Calling
#
# **Goal:** Route queries to simple tools chosen by the model.
#
# **Inputs:** Natural-language questions
#
# **Outputs:** Tool results
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
# Minimal tool registry (no LLM yet). Replace with your LLM of choice.
import math
TOOLS = {
    "sqrt": lambda x: math.sqrt(float(x)),
    "echo": lambda x: x,
}
def call_tool(name, arg):
    return TOOLS[name](arg)
print("Tools ready:", list(TOOLS))
