# %% [markdown]
# # 10a — Prompting Foundations
#
# **Goal:** Explore zero/one/few-shot prompting.
#
# **Inputs:** Prompts and examples
#
# **Outputs:** Comparative generations
#
# > Tip: Fill your API keys in `.env` (copy from `.env.example`). Never commit secrets.

# %%
examples = [
    ("zero-shot", "List three pros of unit tests."),
    ("few-shot", "Q: What is RAG?\nA: Retrieval-Augmented Generation.\n\nQ: Name two benefits of RAG.\nA:"),
]
for label, p in examples:
    print(f"\n[{label}] -> {p}\nGenerated: <your-model-output>")
